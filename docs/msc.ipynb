# %%
import ipcoal
from toytree.drawing.src.draw_demography import EmbeddingPlot

# %%
S, G, I = ipcoal.msc.get_test_data()

# %% [markdown]
# ### Utilities

# %%
ipcoal.msc.get_genealogy_embedding_table(S, G, I)
# Out:
#        start      stop  st_node      neff  nedges      dist  gidx       edges
# 0        0.0  100000.0        0  100000.0       3  100000.0     0   [0, 1, 2]
# 1   100000.0  200000.0        0  100000.0       2  100000.0     0      [2, 7]
# 2        0.0  120000.0        1  100000.0       2  120000.0     0      [3, 4]
# 3   120000.0  200000.0        1  100000.0       1   80000.0     0         [8]
# 4        0.0  400000.0        2  100000.0       1  400000.0     0         [5]
# 5        0.0  600000.0        3  100000.0       1  600000.0     0         [6]
# 6   200000.0  300000.0        4  100000.0       3  100000.0     0   [2, 7, 8]
# 7   300000.0  400000.0        4  100000.0       2  100000.0     0      [7, 9]
# 8   400000.0  450000.0        5  100000.0       3   50000.0     0   [5, 7, 9]
# 9   450000.0  600000.0        5  100000.0       2  150000.0     0     [5, 10]
# 10  600000.0  650000.0        6  100000.0       3   50000.0     0  [5, 6, 10]
# ...

# %%
gtree, imap = ipcoal.msc.get_embedded_genealogy(S, nsamples=4)
EmbeddingPlot(S, gtree, imap, blend=True).draw();
# Out:
# <div class="toyplot" id="t2b9075e0430c4666b0a6b79ac480421c" style="text-align:center"><svg class="toyplot-canvas-Canvas" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg" width="350.0px" height="300.0px" viewBox="0 0 350.0 300.0" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" id="t1f19bfb53e934f4185e4b66684b93d8e"><g class="toyplot-coordinates-Cartesian" id="t747eb798fdac4bb2b559adec214758f2"><clipPath id="t9d3ebb7385b54fd7a4b40423fb43d7f3"><rect x="40.0" y="40.0" width="270.0" height="220.0"></rect></clipPath><g clip-path="url(#t9d3ebb7385b54fd7a4b40423fb43d7f3)"><g class="toyplot-mark-FillBoundaries" style="stroke:none" id="t00e146e48a344ab9a1fe3df3bd6174e9"><polygon poin
# ...

# %%
gtree, imap = ipcoal.msc.get_embedded_genealogy(S, nsamples={"A": 1, "B": 2, "C": 3, "D": 4})
EmbeddingPlot(S, gtree, imap, blend=True).draw();
# Out:
# <div class="toyplot" id="t42eb05d6a80444859a525fadaf137649" style="text-align:center"><svg class="toyplot-canvas-Canvas" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg" width="350.0px" height="300.0px" viewBox="0 0 350.0 300.0" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" id="t0db28433e353451984d4006fb5cc9ecb"><g class="toyplot-coordinates-Cartesian" id="ta0eb9016f2a348108eea61ccbecc2611"><clipPath id="t46b8169101964ed68bd2d8302faaeee2"><rect x="40.0" y="40.0" width="270.0" height="220.0"></rect></clipPath><g clip-path="url(#t46b8169101964ed68bd2d8302faaeee2)"><g class="toyplot-mark-FillBoundaries" style="stroke:none" id="td2e5d706be174fbfb624abf4f4f3a782"><polygon poin
# ...

# %%
# Out:
# <div class="toyplot" id="t834488653d14481ea91615ff62427b3e" style="text-align:center"><svg class="toyplot-canvas-Canvas" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg" width="350.0px" height="300.0px" viewBox="0 0 350.0 300.0" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" id="t5e61e43b56e846a996ce096a6a26de5e"><g class="toyplot-coordinates-Cartesian" id="t0310e1f671c0403bb0c5de95ef3d5688"><clipPath id="tebc727289f57484891d6096c97252d6a"><rect x="40.0" y="40.0" width="270.0" height="220.0"></rect></clipPath><g clip-path="url(#tebc727289f57484891d6096c97252d6a)"><g class="toyplot-mark-FillBoundaries" style="stroke:none" id="te976802e42e34dbbafb0e2a90eff7716"><polygon poin
# ...
