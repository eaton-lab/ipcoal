# %% [markdown]
# # Visualization

# %%
import toytree
import ipcoal

# %% [markdown]
# ## Trees
# Species trees, gene trees, or genealogies...

# %% [markdown]
# ## Demographic models
# Demographic models representing a single population or multiple populations...
#
# Note: The demographic model visualization source code is actually in the `toytree` package, but ...

# %%
S, G, I = ipcoal.msc.get_test_data()

# %%
newick = "((A,B),C);"

# %%
model = ipcoal.Model(newick, Ne=10000)

# %%
model.draw_demography();
# Out:
# <div class="toyplot" id="t602e391931d64405aa6e527f1d0127bf" style="text-align:center"><svg class="toyplot-canvas-Canvas" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg" width="350.0px" height="300.0px" viewBox="0 0 350.0 300.0" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" id="t7ceed8b69505402daca02e0fc48870a5"><g class="toyplot-coordinates-Cartesian" id="t61f81f4631cb4a0a8116c51011523ac9"><clipPath id="tb6ede77c77c447d9b3071706c74d26f3"><rect x="40.0" y="40.0" width="270.0" height="220.0"></rect></clipPath><g clip-path="url(#tb6ede77c77c447d9b3071706c74d26f3)"><g class="toyplot-mark-FillBoundaries" style="stroke:none" id="t4ccd92156c264f4c82ef127c9fbd2dc5"><polygon poin
# ...

# %% [markdown]
# ### Show substitutions
