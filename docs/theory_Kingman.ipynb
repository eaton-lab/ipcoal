# %% [markdown]
# # Kingman coalescent
#
# The Kingman coalescent is a statistical model that describes the distribution of waiting times between coalescent events in a panmictic neutrally evolving population. This model has two major applications in evolutionary genetics. First, it provides a generative model by which to stochastically build genealogical trees by sampling waiting times between coalescent events. Given a parameterized model of population, minimally described by its effective population size (Ne), a distribution of genealogies
#
#
# By sampling many genealogies we can generate a distribution of genealogical histories given a parameterized model of a population. Secondly, the coalescent model is also important for serving as a probability density from which we can calculate the likelihood of one or more observed genealogies given a parameterized demographic model.

# %%
import ipcoal

# %% [markdown]
# ### A motivating example,

# %%
# setup a single-population demographic model
model = ipcoal.Model(Ne=1000, nsamples=6, seed_trees=123)

# simulate several independent genealogical histories under this model
model.sim_trees(nloci=100, nsites=1)

# draw the first genealogy embedded in the demographic model
model.draw_demography(idx=1);
# Out:
# <div class="toyplot" id="t60ee550f441a4c0b95ecc13abffc1c3a" style="text-align:center"><svg class="toyplot-canvas-Canvas" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg" width="350.0px" height="300.0px" viewBox="0 0 350.0 300.0" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" id="tf0a5f6c9842d4303a29f7554fc92769e"><g class="toyplot-coordinates-Cartesian" id="tab6bd25ecdac4343b3fb40e0eda6b763"><clipPath id="t04faa36a40594beaa08801690a450c83"><rect x="40.0" y="40.0" width="270.0" height="220.0"></rect></clipPath><g clip-path="url(#t04faa36a40594beaa08801690a450c83)"><g class="toyplot-mark-FillBoundaries" style="stroke:none" id="tee3146a9f8d94a7f846e7fde007b2223"><polygon points="50.0,223.90699453932038 50.0,223.90699453932038 300.0,223.90699453932038 300.0,223.90699453932038 300.0,223.90699453932038 300.0,50.0 50.0,50.0 50.0,223.90699453932038" style="fill:rgb(0%,0%,0%);fill-opacity:1.0;opacity:0.25;stroke:none"><title>idx=0
# Ne=1e+03
# Tc=inf
# Tg=inf</title></polygon></g><g class="toyplot-mark-Plot" style="fill:none" id="ta77c29417445409db69c7fc698497507"><g class="toyplot-Series"><path d="M 85.71428571428572 223.90699453932038 L 103.57142857142856 187.7037199314742" style="stroke:rgb(10.6%,62%,46.7%);stroke-opacity:1.0;stroke-width:2.0"></path></g></g><g class="toyplot-mark-Plot" style="fill:none" id="t79d04b6397f04e22940fc1026018f536"><g class="toyplot-Series"><path d="M 121.42857142857142 223.90699453932038 L 103.57142857142856 187.7037199314742" style="stroke:rgb(10.6%,62%,46.7%);stroke-opacity:1.0;stroke-width:2.0"></path></g></g><g class="toyplot-mark-Plot" style="fill:none" id="t30be528901d146bfb2db5d91746b339b"><g class="toyplot-Series"><path d="M 157.1428571428571 223.90699453932038 L 188.39285714285714 126.34853531407086" style="stroke:rgb(10.6%,62%,46.7%);stroke-opacity:1.0;stroke-width:2.0"></path></g></g><g class="toyplot-mark-Plot" style="fill:none" id="t0b2e5c94effe44a89b2bb1da0e02006c"><g class="toyplot-Series"><path d="M 192.85714285714283 223.90699453932038 L 219.64285714285714 201.61764063563115" style="stroke:rgb(10.6%,62%,46.7%);stroke-opacity:1.0;stroke-width:2.0"></path></g></g><g class="toyplot-mark-Plot" style="fill:none" id="t273d1408d54d4b9c8e4ca035b00a7fa0"><g class="toyplot-Series"><path d="M 228.57142857142853 223.90699453932038 L 246.4285714285714 212.00391597353126" style="stroke:rgb(10.6%,62%,46.7%);stroke-opacity:1.0;stroke-width:2.0"></path></g></g><g class="toyplot-mark-Plot" style="fill:none" id="t53628927d5d94cfa8477186dc57ef781"><g class="toyplot-Series"><path d="M 264.2857142857143 223.90699453932038 L 246.4285714285714 212.00391597353126" style="stroke:rgb(10.6%,62%,46.7%);stroke-opacity:1.0;stroke-width:2.0"></path></g></g><g class="toyplot-mark-Plot" style="fill:none" id="t55210af43e654674b4f06259ad59be01"><g class="toyplot-Series"><path d="M 103.57142857142856 187.7037199314742 L 145.98214285714283 50.0" style="stroke:rgb(10.6%,62%,46.7%);stroke-opacity:1.0;stroke-width:2.0"></path></g></g><g class="toyplot-mark-Plot" style="fill:none" id="tda0192247aea406c888646e4fc9db648"><g class="toyplot-Series"><path d="M 246.4285714285714 212.00391597353126 L 219.64285714285714 201.61764063563115" style="stroke:rgb(10.6%,62%,46.7%);stroke-opacity:1.0;stroke-width:2.0"></path></g></g><g class="toyplot-mark-Plot" style="fill:none" id="tb6f9e89df1ca4ec3957143d9a5cb01fc"><g class="toyplot-Series"><path d="M 219.64285714285714 201.61764063563115 L 188.39285714285714 126.34853531407086" style="stroke:rgb(10.6%,62%,46.7%);stroke-opacity:1.0;stroke-width:2.0"></path></g></g><g class="toyplot-mark-Plot" style="fill:none" id="te40d2c37cfb44dab9388d81fe500c4ec"><g class="toyplot-Series"><path d="M 188.39285714285714 126.34853531407086 L 145.98214285714283 50.0" style="stroke:rgb(10.6%,62%,46.7%);stroke-opacity:1.0;stroke-width:2.0"></path></g></g><g class="toyplot-mark-Text" id="t9fc3ac98ec0845a68f2977cc16574555"><g class="toyplot-Series"><g class="toyplot-Datum" transform="translate(85.71428571428572,223.90699453932038)rotate(90.0)"><text x="9.992" y="3.066" style="fill:rgb(0%,0%,0%);fill-opacity:1.0;font-family:helvetica;font-size:12.0px;font-weight:normal;opacity:1;stroke:none;vertical-align:baseline;white-space:pre">p_2</text></g><g class="toyplot-Datum" transform="translate(121.42857142857142,223.90699453932038)rotate(90.0)"><text x="9.992" y="3.066" style="fill:rgb(0%,0%,0%);fill-opacity:1.0;font-family:helvetica;font-size:12.0px;font-weight:normal;opacity:1;stroke:none;vertical-align:baseline;white-space:pre">p_5</text></g><g class="toyplot-Datum" transform="translate(157.1428571428571,223.90699453932038)rotate(90.0)"><text x="9.992" y="3.066" style="fill:rgb(0%,0%,0%);fill-opacity:1.0;font-family:helvetica;font-size:12.0px;font-weight:normal;opacity:1;stroke:none;vertical-align:baseline;white-space:pre">p_0</text></g><g class="toyplot-Datum" transform="translate(192.85714285714283,223.90699453932038)rotate(90.0)"><text x="9.992" y="3.06 ...

# %%
model.draw_genealogies(shape=(1, 4), shared_axes=True, scale_bar=True);
# Out:
# <div class="toyplot" id="t949bf675561341b5bf2a9daedb4cc40c" style="text-align:center"><svg class="toyplot-canvas-Canvas" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg" width="750.0px" height="250.0px" viewBox="0 0 750.0 250.0" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" id="t5d4ac06b24384aa8a2bdfc2a3c483356"><g class="toyplot-coordinates-Cartesian" id="t927c6769f78a4253b18c3c762aa45aa8"><clipPath id="td39f1506f09d46e3a899a09235eecb54"><rect x="40.0" y="40.0" width="147.5" height="170.0"></rect></clipPath><g clip-path="url(#td39f1506f09d46e3a899a09235eecb54)"><g class="toytree-mark-Toytree" id="t6f647e7acca547388b333b40199e9d3f"><g class="toytree-Edges" style="stroke:rgb(14.5%,14.5%,14.5%);stroke-opacity:1.0;stroke-linecap:round;stroke-width:2;fill:none"><path d="M 75.9 116.5 L 55.5 160.6" id="8,0" style=""></path><path d="M 96.3 142.1 L 78.8 160.6" id="7,1" style=""></path><path d="M 113.8 153.4 L 102.1 160.6" id="6,2" style=""></path><path d="M 113.8 153.4 L 125.4 160.6" id="6,3" style=""></path><path d="M 160.4 104.3 L 148.7 160.6" id="9,4" style=""></path><path d="M 160.4 104.3 L 172.0 160.6" id="9,5" style=""></path><path d="M 96.3 142.1 L 113.8 153.4" id="7,6" style=""></path><path d="M 75.9 116.5 L 96.3 142.1" id="8,7" style=""></path><path d="M 118.1 73.9 L 75.9 116.5" id="10,8" style=""></path><path d="M 118.1 73.9 L 160.4 104.3" id="10,9" style=""></path></g><g class="toytree-AdmixEdges" style="fill:rgb(0.0%,0.0%,0.0%);fill-opacity:0.0;stroke:rgb(90.6%,54.1%,76.5%);stroke-opacity:0.6;font-size:14px;stroke-linecap:round;stroke-width:5"></g><g class="toytree-Nodes" style="fill:rgb(40.0%,76.1%,64.7%);fill-opacity:1.0;stroke:rgb(14.5%,14.5%,14.5%);stroke-opacity:1.0;stroke-width:1.5"><g id="Node-0" transform="translate(55.4839,160.641)"><circle r="3.5"></circle></g><g id="Node-1" transform="translate(78.7903,160.641)"><circle r="3.5"></circle></g><g id="Node-2" transform="translate(102.097,160.641)"><circle r="3.5"></circle></g><g id="Node-3" transform="translate(125.403,160.641)"><circle r="3.5"></circle></g><g id="Node-4" transform="translate(148.71,160.641)"><circle r="3.5"></circle></g><g id="Node-5" transform="translate(172.016,160.641)"><circle r="3.5"></circle></g><g id="Node-6" transform="translate(113.75,153.409)"><circle r="3.5"></circle></g><g id="Node-7" transform="translate(96.2702,142.13)"><circle r="3.5"></circle></g><g id="Node-8" transform="translate(75.877,116.452)"><circle r="3.5"></circle></g><g id="Node-9" transform="translate(160.363,104.336)"><circle r="3.5"></circle></g><g id="Node-10" transform="translate(118.12,73.8897)"><circle r="3.5"></circle></g></g><g class="toytree-TipLabels" style="fill:rgb(14.5%,14.5%,14.5%);fill-opacity:1.0;font-family:Helvetica;font-size:10px;font-weight:300;vertical-align:baseline;white-space:pre;stroke:none"><g class="toytree-TipLabel" transform="translate(55.4839,160.641)rotate(90)"><text x="10.0" y="2.5549999999999997" style="fill:rgb(14.5%,14.5%,14.5%);fill-opacity:1.0">p_3</text></g><g class="toytree-TipLabel" transform="translate(78.7903,160.641)rotate(90)"><text x="10.0" y="2.5549999999999997" style="fill:rgb(14.5%,14.5%,14.5%);fill-opacity:1.0">p_5</text></g><g class="toytree-TipLabel" transform="translate(102.097,160.641)rotate(90)"><text x="10.0" y="2.5549999999999997" style="fill:rgb(14.5%,14.5%,14.5%);fill-opacity:1.0">p_0</text></g><g class="toytree-TipLabel" transform="translate(125.403,160.641)rotate(90)"><text x="10.0" y="2.5549999999999997" style="fill:rgb(14.5%,14.5%,14.5%);fill-opacity:1.0">p_4</text></g><g class="toytree-TipLabel" transform="translate(148.71,160.641)rotate(90)"><text x="10.0" y="2.5549999999999997" style="fill:rgb(14 ...

# %%
model = ipcoal.Model(Ne=1000, nsamples=6, seed_trees=123, store_tree_sequences=True)
model.sim_loci(nloci=1, nsites=1000)
model.draw_genealogy(show_substitutions=True);
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[24], line 3
#       1 model = ipcoal.Model(Ne=1000, nsamples=6, seed_trees=123, store_tree_sequences=True)
#       2 model.sim_loci(nloci=1, nsites=1000)
# ----> 3 model.draw_genealogy(show_substitutions=True);
#
# File ~/Documents/ipcoal/ipcoal/model.py:670, in Model.draw_genealogy(self, idx, show_substitutions, **kwargs)
#     653 def draw_genealogy(
#     654     self,
#     655     idx: Optional[int] = None,
#     656     show_substitutions: bool = False,
#     657     **kwargs,
#     658 ):
#     659     """Return a toytree drawing of a single genealogy.
#     660
#     661     Parameters
#    (...)
#     668         with `store_tree_sequences=True` to retain substitutions.
#     669     """
# --> 670     return draw_genealogy(self, idx, show_substitutions, **kwargs)
#
# File ~/Documents/ipcoal/ipcoal/draw/draw_genealogy.py:59, in draw_genealogy(model, idx, show_substitutions, **kwargs)
#      53         kwargs["scale_bar"] = kwargs.get("scale_bar", True)
#      55         # call the ToyTreeSequence draw function to draw the tree
#      56         # with mutations included. Note: this is where we could
#      57         # alternatively extract mutation info and draw manually
#      58         # on top of a normal tree plot for more flexibility.
# ---> 59         canvas, axes, mark = tseq.draw_tree(idx=tidx, **kwargs)
#      61 else:
#      62     tree = toytree.tree(model.df.genealogy[idx])
#
# File ~/Documents/toytree/toytree/utils/src/toytree_sequence.py:297, in ToyTreeSequence.draw_tree(self, site, idx, mutation_size, mutation_style, mutation_color_palette, show_label, **kwargs)
#     294     tree = self.at_index(idx)
#     296 # draw the tree with kwargs
# --> 297 canvas, axes, mark = tree.draw(**kwargs)
#     299 # standard color palette for mtypes, or user-specified one.
#     300 colormap = (
#     301     mutation_color_palette if mutation_color_palette is not None
#     302     else toytree.color.COLORS1)
#
# AttributeError: 'Node' object has no attribute 'draw'
